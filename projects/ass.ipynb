# %%
import pandas as pd

# %%
df=pd.read_csv('yahoo_finance.csv')

# %%
df
# Out:
#         ticker asset_class                        shortName  \
# 0    000660.KS        INTL                         SK hynix
# 1    005930.KS        INTL                      SamsungElec
# 2    035420.KS        INTL                            NAVER
# 3         AAPL     US_MEGA                       Apple Inc.
# 4     AAVE-USD      CRYPTO                         Aave USD
# ..         ...         ...                              ...
# 446  ^TA125.TA     INDICES                           TA-125
# 447       ^TNX     INDICES  CBOE Interest Rate 10 Year T No
# 448      ^TWII     INDICES  TSEC CAPITALIZATION WEIGHTED ST
# 449       ^TYX     INDICES          Treasury Yield 30 Years
# 450       ^VIX     INDICES            CBOE Volatility Index
#
#                                      longName     symbol exchange  \
# 0                               SK hynix Inc.  000660.KS      KSC
# 1               Samsung Electronics Co., Ltd.  005930.KS      KSC
# ...

# %%
import matplotlib as plt

# %%
df.corr(numeric_only=True)
# Out:
#                            currentPrice  previousClose      open    dayLow  \
# currentPrice                   1.000000       0.999972  0.999997  0.999999
# previousClose                  0.999972       1.000000  0.999925  0.999917
# open                           0.999997       0.999925  1.000000  0.999997
# dayLow                         0.999999       0.999917  0.999997  1.000000
# dayHigh                        0.999998       0.999911  0.999983  0.999975
# ...                                 ...            ...       ...       ...
# asset_class_return_rank       -0.116228      -0.102830 -0.102794 -0.103016
# asset_class_momentum_rank     -0.116041      -0.101312 -0.101367 -0.101586
# fear_greed_proxy              -0.091209      -0.041270 -0.042042 -0.041872
# week52_position_pct            0.059330       0.049979  0.049405  0.049593
# composite_score                0.078617       0.073512  0.073766  0.073897
#
# ...

# %%
plt.scatter(df['currentPrice'],df['volume'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.scatter(df['currentPrice'],df['volume'])
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'

# %%
plt.plot('currentPrice')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.plot('currentPrice')
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
bar=df.groupby('sector')['asset_class_momentum_rank'].mean()

# %%
plt.bar(bar.index,bar.values)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.bar(bar.index,bar.values)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'bar'
