# %%
import pandas as pd

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#for info

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %%
#head method

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
df.dtypes
# Out:
# gender                           str
# race/ethnicity                   str
# parental level of education      str
# lunch                            str
# test preparation course          str
# math score                     int64
# reading score                  int64
# writing score                  int64
# dtype: object

# %%
#df[colname]

df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
df[['gender','lunch']]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [1000 rows x 2 columns]

# %%
df[['gender','lunch','writing score']]
# Out:
#      gender         lunch  writing score
# 0    female      standard             74
# 1    female      standard             88
# 2    female      standard             93
# 3      male  free/reduced             44
# 4      male      standard             75
# ..      ...           ...            ...
# 995  female      standard             95
# 996    male  free/reduced             55
# 997  female  free/reduced             65
# 998  female      standard             77
# 999  female  free/reduced             86
#
# [1000 rows x 3 columns]

# %%
# slicing

df.iloc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.iloc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.iloc[:,2]
# Out:
# 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: str

# %%
df.iloc[0,1]
# Out:
# 'group B'

# %%
df.iloc[1:,1:]
# Out:
#     race/ethnicity parental level of education         lunch  \
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# 5          group B          associate's degree      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
df.iloc[[0,3]]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44

# %%
df.iloc[[0,3],[0,2]]
# Out:
#    gender parental level of education
# 0  female           bachelor's degree
# 3    male          associate's degree

# %%
df.iloc[[0,3],:]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44

# %%
df.iloc[0:3]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.iloc[:,'gender']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:993, in _LocationIndexer._validate_tuple_indexer(self, key)
#     992 try:
# --> 993     self._validate_key(k, i)
#     994 except ValueError as err:
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1635, in _iLocIndexer._validate_key(self, key, axis)
#    1634 else:
# -> 1635     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
df.iloc[:,['gender']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.iloc[:,['gender']]
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1711, in _iLocIndexer._getitem_tuple(self, tup)
#    1710 def _getitem_tuple(self, tup: tuple):
# -> 1711     tup = self._validate_tuple_indexer(tup)
#    1712     with suppress(IndexingError):
#    1713         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[::2]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.iloc[-1,:]
# Out:
# gender                               female
# race/ethnicity                      group D
# parental level of education    some college
# lunch                          free/reduced
# test preparation course                none
# math score                               77
# reading score                            86
# writing score                            86
# Name: 999, dtype: object

# %%
##loc slicing

df.loc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[:,:,2]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc[:,:,2]
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1389, in _LocIndexer._getitem_tuple(self, tup)
#    1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
# -> 1389 tup = self._validate_tuple_indexer(tup)
#    1391 # ugly hack for GH #836
# ...

# %%
df.loc[:,'parental level of education']
# Out:
# 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: str

# %%
df.loc[0:5:1,'gender']
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# Name: gender, dtype: str

# %%
df.loc[[0,3]]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44

# %%
df.loc[0,['gender']]
# Out:
# gender    female
# Name: 0, dtype: str

# %%
df.loc[10:,'gender':'lunch']
# Out:
#      gender race/ethnicity parental level of education         lunch
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
# [990 rows x 4 columns]

# %%
df.loc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
df.loc[0,'gender','lunch']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.loc[0,'gender','lunch']
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1389, in _LocIndexer._getitem_tuple(self, tup)
#    1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
# -> 1389 tup = self._validate_tuple_indexer(tup)
#    1391 # ugly hack for GH #836
# ...

# %%
df.loc[0:10:2,['gender','lunch']]
# Out:
#     gender         lunch
# 0   female      standard
# 2   female      standard
# 4     male      standard
# 6   female      standard
# 8     male  free/reduced
# 10    male      standard

# %%
#filter based on condition

df['gender']=='female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
df['gender']!='female'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df['gender']=='female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['gender','lunch']=='female','standard'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: ('gender', 'lunch')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['gender','lunch']=='female','standard'
#
# ...

# %%
#filter female record and lunch is standard
df[(df['gender']=='female') & (df['lunch']=='standard')]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
#Filter female records those who scored above 70 in maths
[(df['gender']=='female') & (df['math score']>70)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#filter male records and lunch is standard
df[(df['gender']=='male') & (df['lunch']=='standard')]
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score
# 4                      none          76             78             75
# ...

# %%
# And final count of filtered records from 1 & 2
#Count of female records with 70 above will be 170 records
#Count of male records and lunch stander will be 316 records

#it is shown in result at the end of the table

# %%
df['gender'].unique()
df['race/ethnicity'].unique()
# Out:
# <StringArray>
# ['group B', 'group C', 'group A', 'group D', 'group E']
# Length: 5, dtype: str

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
#For getting all catogorical columns unique values and store in in the column names
l=['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %%
for i in l:
    print(f"{i} => {df[i].unique()}")
# Out:
# gender => <StringArray>
# ['female', 'male']
# Length: 2, dtype: str
# race/ethnicity => <StringArray>
# ['group B', 'group C', 'group A', 'group D', 'group E']
# Length: 5, dtype: str
# parental level of education => <StringArray>
# [ 'bachelor's degree',       'some college',    'master's degree',
#  'associate's degree',        'high school',   'some high school']
# Length: 6, dtype: str
# lunch => <StringArray>
# ['standard', 'free/reduced']
# Length: 2, dtype: str
# test preparation course => <StringArray>
# ['none', 'completed']
# Length: 2, dtype: str

# %%
#to get the count of the unique values
for i in l:
    print(f"{i} => {df[i].nunique()}")
# Out:
# gender => 2
# race/ethnicity => 5
# parental level of education => 6
# lunch => 2
# test preparation course => 2

# %%
# by using len method to find count
for i in l:
    a= df[i].unique()
    b=len(a)
    print(f"{i} => {b}")
# Out:
# gender => 2
# race/ethnicity => 5
# parental level of education => 6
# lunch => 2
# test preparation course => 2

# %%
# value_counts()

df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
import pandas

# %%
## isnull()

#Using list created a dataframe table
data=[[22,None],[None,None],[None,25000],[30,40000],[60,150000]]
col=['age','sal']
pandas.DataFrame(data,columns=col)
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#Using dictionary created a dataframe table
df=pandas.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.mean()
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14380 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14381 def mean(
#   14382     self,
# ...

# %%
df.mean("sal")
# Out:
# C:\Users\kruth\AppData\Local\Temp\ipykernel_1908\847834635.py:1: Pandas4Warning: Starting with pandas version 4.0 all arguments of mean will be keyword-only.
#   df.mean("sal")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     524         except KeyError as err:
# --> 525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#
# KeyError: 'sal'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1908\847834635.py in ?()
# ----> 1 df.mean("sal")
#
# ...

# %%
df.mean(numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df.mean(numeric_only=True,axis=0)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df.mean(numeric_only=True,axis=1)
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Length: 1000, dtype: float64

# %%
df.median(numeric_only=True,axis=0)
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
df.median(numeric_only=True,axis=1)
# Out:
# 0      72.0
# 1      88.0
# 2      93.0
# 3      47.0
# 4      76.0
#        ...
# 995    95.0
# 996    55.0
# 997    65.0
# 998    77.0
# 999    86.0
# Length: 1000, dtype: float64

# %%
df.mode(numeric_only=True,axis=0)
# Out:
#    math score  reading score  writing score
# 0          65             72             74

# %%
df.mode(numeric_only=True,axis=1)
# Out:
#         0     1     2
# 0    72.0   NaN   NaN
# 1    69.0  88.0  90.0
# 2    90.0  93.0  95.0
# 3    44.0  47.0  57.0
# 4    75.0  76.0  78.0
# ..    ...   ...   ...
# 995  88.0  95.0  99.0
# 996  55.0   NaN   NaN
# 997  59.0  65.0  71.0
# 998  68.0  77.0  78.0
# 999  86.0   NaN   NaN
#
# [1000 rows x 3 columns]

# %%
df.agg(['min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.agg(['min','max','mean'])
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:12030, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   12027 axis = self._get_axis_number(axis)
#   12029 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 12030 result = op.agg()
#   12031 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   12032 return result
#
# File c:\Users\kruth\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1027, in FrameApply.agg(self)
#    1025 result = None
#    1026 try:
# -> 1027     result = super().agg()
#    1028 finally:
#    1029     self.obj = obj
#
# ...

# %%
df[['reading score','math score', 'writing score']].agg(['max','mean','min'])
# Out:
#       reading score  math score  writing score
# max         100.000     100.000        100.000
# mean         69.169      66.089         68.054
# min          17.000       0.000         10.000

# %%
df.agg({'reading score':'max',
        'writing score':'min',
        'math score': 'mean'})
# Out:
# reading score    100.000
# writing score     10.000
# math score        66.089
# dtype: float64

# %%
df.mode()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          65             72             74

# %%
#Shape

df.shape
# Out:
# (1000, 8)

# %%
#Count
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
#isnull

df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Using dictionary created a dataframe table
df=pandas.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 #Using dictionary created a dataframe table
# ----> 2 df=pandas.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
#       3 df
#
# NameError: name 'pandas' is not defined

# %%
import pandas as pd

# %%
#Using dictionary created a dataframe table
df=pd.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#isnull
df.isna()
# Out:
#      age    sal
# 0  False   True
# 1   True   True
# 2   True  False
# 3  False  False
# 4  False  False

# %%
#for getting the count of null values of each column
df.isna().sum()
# Out:
# age    2
# sal    2
# dtype: int64

# %%
#for getting the count of null values of entire table
df.isna().sum().sum()
# Out:
# np.int64(4)

# %%
#not null

#notnull()/notna()


df.notnull()
# Out:
#      age    sal
# 0   True  False
# 1  False  False
# 2  False   True
# 3   True   True
# 4   True   True

# %%
df.notna()
# Out:
#      age    sal
# 0   True  False
# 1  False  False
# 2  False   True
# 3   True   True
# 4   True   True

# %%
df.notnull().sum()
# Out:
# age    3
# sal    3
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(6)

# %%
df['age'].notna()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
df[df['age'].notna()]
# Out:
#     age       sal
# 0  22.0       NaN
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Using dictionary created a dataframe table
df=pd.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#fillna(value)

#df.fillna(0)
# Out:
#     age       sal
# 0  22.0       0.0
# 1   0.0       0.0
# 2   0.0   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#df=df.fillna(0)

# %%
#df
# Out:
#     age       sal
# 0  22.0       0.0
# 1   0.0       0.0
# 2   0.0   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#df.fillna(value,inplace=True)
#df=df.fillna(0,inplace=True) #-> None
#df.fillna(0,inplace=True)

# %%
#df

# %%
#Using dictionary created a dataframe table
df=pd.DataFrame({'age':[22,None,None,30,60],'sal':[None,None,25000,40000,150000]})
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
#df.fillna({'age':df['age'].mean(),

#           'sal':df['sal'].median()})

# %%
df
# Out:
#     age       sal
# 0  22.0       NaN
# 1   NaN       NaN
# 2   NaN   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
df.fillna(method='ffill')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.fillna(method='ffill')
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
df.ffill()
# Out:
#     age       sal
# 0  22.0       NaN
# 1  22.0       NaN
# 2  22.0   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0

# %%
df.bfill()
# Out:
#     age       sal
# 0  22.0   25000.0
# 1  30.0   25000.0
# 2  30.0   25000.0
# 3  30.0   40000.0
# 4  60.0  150000.0
