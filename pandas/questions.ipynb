# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('Sample-Superstore.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],format="mixed")

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'],format="mixed")

# %%
df['Order_Year']=df['Order Date'].dt.year

# %%
df['Order_Month']=df['Order Date'].dt.month

# %%
df['Ship_Year']=df['Ship Date'].dt.year

# %%
df['Ship_Month']=df['Ship Date'].dt.month

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                    str
# Order Date       datetime64[us]
# Ship Date        datetime64[us]
# Ship Mode                   str
# Customer ID                 str
# Customer Name               str
# Segment                     str
# Country                     str
# City                        str
# State                       str
# Postal Code               int64
# Region                      str
# Product ID                  str
# Category                    str
# Sub-Category                str
# Product Name                str
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# od               datetime64[us]
# sd               datetime64[us]
# Order_Year                int32
# Order_Month               int32
# Ship_Year                 int32
# Ship_Month                int32
# ship Date        datetime64[us]
# dtype: object

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Quantity  \
# 0      Claire Gute   Consumer  United States        Henderson  ...        2
# 1      Claire Gute   Consumer  United States        Henderson  ...        3
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...        2
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...        5
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...        2
#
# ...

# %%
df.drop('od',axis=1,inplace=True)

# %%
df.drop('sd',axis=1,inplace=True)

# %%
df.drop('ship Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#                                         Product Name     Sales Quantity  \
# ...

# %%
df['Postal Code']
# Out:
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
#         ...
# 9989    33180
# 9990    92627
# 9991    92627
# 9992    92627
# 9993    92683
# Name: Postal Code, Length: 9994, dtype: int64

# %%
df['Postal Code'].astype(int)
# Out:
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
#         ...
# 9989    33180
# 9990    92627
# 9991    92627
# 9992    92627
# 9993    92683
# Name: Postal Code, Length: 9994, dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.dtypes=='object'
# Out:
# Row ID           False
# Order ID         False
# Order Date       False
# Ship Date        False
# Ship Mode        False
# Customer ID      False
# Customer Name    False
# Segment          False
# Country          False
# City             False
# State            False
# Postal Code      False
# Region           False
# Product ID       False
# Category         False
# Sub-Category     False
# Product Name     False
# Sales            False
# Quantity         False
# Discount         False
# Profit           False
# Order_Year       False
# Order_Month      False
# Ship_Year        False
# Ship_Month       False
# dtype: bool

# %%
plt.boxplot(df['Sales'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eb335adfd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eb335ae270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eb335ade80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eb335ae510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eb335ae660>],
#  'means': []}

# %%
def z_score(col):
    X=df[col]
    x_mean=df[col].mean()
    x_std=df[col].std()
    return (X-x_mean)/x_std
#z_score('Rating')
df['Sales_Z']=z_score('Sales')
df['Sales_Z']
# Out:
# 0       0.051508
# 1       0.805593
# 2      -0.345350
# 3       1.167630
# 4      -0.332919
#           ...
# 9989   -0.328298
# 9990   -0.221258
# 9991    0.046078
# 9992   -0.321315
# 9993    0.021343
# Name: Sales_Z, Length: 9994, dtype: float64

# %%
def outliers(col):
    l=[]
    for val in df[col]:
        if abs(val)>3:
            l.append(val)
    return l
x=outliers('Sales_Z')
len(x)
# Out:
# 127

# %%
df['Sales_Z']
# Out:
# 0       0.051508
# 1       0.805593
# 2      -0.345350
# 3       1.167630
# 4      -0.332919
#           ...
# 9989   -0.328298
# 9990   -0.221258
# 9991    0.046078
# 9992   -0.321315
# 9993    0.021343
# Name: Sales_Z, Length: 9994, dtype: float64

# %%
def z_score(col):
    X=df[col]
    x_mean=df[col].mean()
    x_std=df[col].std()
    return (X-x_mean)/x_std
#z_score('Rating')
df['Profit_Z']=z_score('Profit')
df['Profit_Z']
# Out:
# 0       0.056590
# 1       0.815013
# 2      -0.092997
# 3      -1.757397
# 4      -0.111587
#           ...
# 9989   -0.104816
# 9990   -0.055595
# 9991   -0.039544
# 9992   -0.065470
# 9993    0.189068
# Name: Profit_Z, Length: 9994, dtype: float64

# %%
def outliers(col):
    l=[]
    for val in df[col]:
        if abs(val)>3:
            l.append(val)
    return l
x=outliers('Profit_Z')
len(x)
# Out:
# 107

# %%
df['Profit_Z']
# Out:
# 0       0.056590
# 1       0.815013
# 2      -0.092997
# 3      -1.757397
# 4      -0.111587
#           ...
# 9989   -0.104816
# 9990   -0.055595
# 9991   -0.039544
# 9992   -0.065470
# 9993    0.189068
# Name: Profit_Z, Length: 9994, dtype: float64

# %%
def z_score(col):
    X=df[col]
    x_mean=df[col].mean()
    x_std=df[col].std()
    return (X-x_mean)/x_std
#z_score('Rating')
df['Profit_Z']=z_score('Profit')
df['Sales_Z']=z_score('Sales')
df['Profit_Z']
df['Sales_Z']
# Out:
# 0       0.051508
# 1       0.805593
# 2      -0.345350
# 3       1.167630
# 4      -0.332919
#           ...
# 9989   -0.328298
# 9990   -0.221258
# 9991    0.046078
# 9992   -0.321315
# 9993    0.021343
# Name: Sales_Z, Length: 9994, dtype: float64

# %%
def outliers(col):
    l=[]
    for val in df[col]:
        if abs(val)>3:
            l.append(val)
    return l
x=outliers('Profit_Z')
y=outliers('Sales_Z')
len(x) & len(y)
# Out:
# 107

# %%
df.drop(['Row ID','Customer ID'], axis=1,inplace=True)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode    Customer Name  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class  Darrin Van Huff
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code  ...  \
# 0   Consumer  United States        Henderson    Kentucky        42420  ...
# 1   Consumer  United States        Henderson    Kentucky        42420  ...
# 2  Corporate  United States      Los Angeles  California        90036  ...
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  ...
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  ...
#
# ...

# %%
df['Customer Name'].nunique()
# Out:
# 793

# %%
df['Country'].nunique()
# Out:
# 1

# %%
df['Segment'].nunique()
# Out:
# 3

# %%
df['City'].nunique()
# Out:
# 531

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['Postal Code'].nunique()
# Out:
# 631

# %%
sns.barplot(x=df['Segment'],y=df['Sales'])
# Out:
# <Axes: xlabel='Segment', ylabel='Sales'>

# %%
df.groupby('Segment')['Sales'].mean().sort_values()
# Out:
# Segment
# Consumer       223.733644
# Corporate      233.823300
# Home Office    240.972041
# Name: Sales, dtype: float64

# %%
df['Ship Mode'].nunique()
# Out:
# 4

# %%
sns.barplot(x=df['Ship Mode'],y=df['Sales'])
# Out:
# <Axes: xlabel='Ship Mode', ylabel='Sales'>

# %%
df.groupby('Ship Mode')['Sales'].mean().sort_values()
# Out:
# Ship Mode
# Standard Class    227.583067
# First Class       228.497024
# Second Class      236.089239
# Same Day          236.396179
# Name: Sales, dtype: float64

# %%
df.groupby('Ship_Month')['Sales'].mean().sort_values()
# Out:
# Ship_Month
# 7     205.507130
# 4     209.730010
# 5     210.896181
# 6     211.172390
# 2     211.563186
# 9     224.654245
# 1     227.088567
# 8     228.713881
# 11    230.279765
# 12    242.016555
# 10    246.362278
# 3     293.965193
# Name: Sales, dtype: float64

# %%
df.groupby('Ship Mode')['Profit'].mean().sort_values()
# Out:
# Ship Mode
# Standard Class    27.494770
# Same Day          29.266591
# Second Class      29.535545
# First Class       31.839948
# Name: Profit, dtype: float64

# %%
df.groupby('Ship_Month')['Sales'].mean().sort_values()
# Out:
# Ship_Month
# 7     205.507130
# 4     209.730010
# 5     210.896181
# 6     211.172390
# 2     211.563186
# 9     224.654245
# 1     227.088567
# 8     228.713881
# 11    230.279765
# 12    242.016555
# 10    246.362278
# 3     293.965193
# Name: Sales, dtype: float64

# %%
df.groupby('Order_Month')['Sales'].mean().sort_values()
# Out:
# Order_Month
# 2     199.170838
# 4     206.230731
# 7     207.377601
# 5     210.923553
# 6     212.996763
# 9     222.451154
# 8     225.274877
# 12    231.032318
# 11    239.606438
# 10    244.594609
# 1     249.146550
# 3     294.548116
# Name: Sales, dtype: float64

# %%
df.groupby('Order_Year')['Sales'].mean().sort_values()
# Out:
# Order_Year
# 2017    221.381418
# 2015    223.849909
# 2016    235.487282
# 2014    242.974159
# Name: Sales, dtype: float64

# %%
df.groupby('Order_Month')['Sales'].mean().sort_values()
# Out:
# Order_Month
# 2     199.170838
# 4     206.230731
# 7     207.377601
# 5     210.923553
# 6     212.996763
# 9     222.451154
# 8     225.274877
# 12    231.032318
# 11    239.606438
# 10    244.594609
# 1     249.146550
# 3     294.548116
# Name: Sales, dtype: float64

# %%
df.groupby('Order_Month')['Profit'].mean().sort_values()
# Out:
# Order_Month
# 4     17.346462
# 7     19.482626
# 1     23.974924
# 11    24.111779
# 9     26.650380
# 6     29.687302
# 5     30.491575
# 12    30.801983
# 8     30.845522
# 2     34.315369
# 10    38.808353
# 3     41.084321
# Name: Profit, dtype: float64

# %%
df.groupby('Order_Year')['Profit'].mean().sort_values()
# Out:
# Order_Year
# 2014    24.858994
# 2017    28.212340
# 2015    29.314274
# 2016    31.617771
# Name: Profit, dtype: float64
